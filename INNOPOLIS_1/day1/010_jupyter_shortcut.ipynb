# %%
# Edit mode : Enter
# Command mode : ESC

# %%
# 셀 추가 (Command mode에서)
# 현재 셀 위로 : a
# 현재 셀 아래로 : b

# %%
# 셀 삭제 (Command mode에서) : dd

# %%
# 선택한 셀을
# 복사하기 : c
# 잘라내기 : x

# %%
# 셀 붙여넣기
# 선택한 셀 위로 : Shift + v
# 선택한 셀 아래로 : v

# %%
# 셀에 라인 추가하기 (Command mode에서) : l

# %%
# 셀 변경하기 (Command mode에서)
# code : y
# markdown : m

# %%
# 해당 셀을 실행하기 : Ctrl + Enter

# %%
# 해당 셀을 실행하고 아래에 셀 선택 : Shift + Enter

# %%
# 코드 자동 완성 : Tab
str.

# %%
str?

# %% [markdown]
# # Jupyter 맛보기

# %% [markdown]
# ### markdown
# 문서처럼 작성할 수도 있습니다.

# %%
print("당연히 코딩도 할 수 있습니다.")
# Out:
# 당연히 코딩도 할 수 있습니다.

# %%
from IPython.display import Image
Image(url="data:image/jpeg;base64,...", width=300, height=150)
# Out:
# <img src="data:image/jpeg;base64,..." width="300" height="150"/>

# %%
def sample(arg) :
    print("샘플 데이터는 {}입니다.".format(arg))

# %%
sample?

# %%
arg = 4

# %%
arg
